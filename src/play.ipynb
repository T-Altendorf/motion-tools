# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import constants
import api
from api import MotionAPI, GoogleCalendarAPI
import json

print("MOtion API Key: ", constants.MOTION_API_KEY)
motion_api = MotionAPI(constants.MOTION_API_KEY)

schedules = motion_api.get_schedules()
print(json.dumps(schedules, indent=4))
# Out:
# MOtion API Key:  pAAphIgWR3ffB+N0Fv1yLbOZy3wFh+Cx4BBL5C1/IUM=
# key: pAAphIgWR3ffB+N0Fv1yLbOZy3wFh+Cx4BBL5C1/IUM=, url: https://api.usemotion.com/v1/schedules, params: None, data: None
# [
#     {
#         "name": "Evenings",
#         "timezone": "Europe/Berlin",
#         "isDefaultTimezone": true,
#         "schedule": {
#             "monday": [
#                 {
#                     "end": "22:00",
#                     "start": "19:00"
#                 }
#             ],
#             "tuesday": [
#                 {
#                     "end": "22:00",
#                     "start": "19:00"
#                 }
#             ],
#             "wednesday": [
#                 {
#                     "end": "22:00",
#                     "start": "19:00"
#                 }
#             ],
#             "thursday": [
#                 {
#                     "end": "22:00",
#                     "start": "19:00"
#                 }
#             ],
# ...

# %%
import re

regex_task = r"\d+[-_]+([^\-_].*)"
regex_week = r".*?_(\d{2})_"

filename = "Ethics4NLP_lecture_06_privacy_2.pdf"

task = re.search(regex_task, filename).group(1)
week = re.search(regex_week, filename).group(1)

print("Task: ", task)
print("Week: ", week)
# Out:
# Task:  privacy_2.pdf
# Week:  06
